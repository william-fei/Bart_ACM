# %% [markdown]
# This is for installing and capturing missing libraries.

# %% [markdown]
# The following conda install executed outside of a jupyter lab session can update the kernel being used by a jupyter session, making the missing lib import'able.
#
# The switch -c conda-forge makes the difference of avoiding version conflicts.
#
# !conda install -y -c conda-forge matplotlib
# took more 10 minutes to complete. I wish there is a faster approach.

# %% [markdown]
# Using the following of pip is much faster.
#
# But after executing it inside the jupyter session, the kernel used by the notebook needs to be restarted to take effect.

# %%
import sys
# !{sys.executable} -m pip install --user seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 3.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from seaborn) (1.24.1)
# Requirement already satisfied: pandas>=0.25 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from seaborn) (3.6.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2

# %%
# !conda install -y -c conda-forge matplotlib # It does have effect, sklearn still cannot be imported afeter the install and restarting the kernel
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                           |                                       failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - argon2-cffi -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - asttokens -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.9,<3.10.0a0|>=3.5,<3.6.0a0']
#   - backcall -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0']
#   - importlib_metadata -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0']
#   - ipython_genutils -> python[version='>=2.7,<2.8.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - jinja2 -> python[version='>=3.11,<3.12.0a0']
#   - pexpect -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.5,<3.6.0a0']
#   - ptyprocess -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0']
#   - pyct-core -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - python-dateutil -> python[version='>=3.8,<3.9.0a0|>=3.9,<3.10.0a0']
#   - rfc3339-validator -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.9,<3.10.0a0|>=3.5,<3.6.0a0']
#   - six -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.9,<3.10.0a0|>=3.5,<3.6.0a0']
#   - sniffio -> python[version='>=3,<3.7']
#   - soupsieve -> python[version='>=3.5,<3.6.0a0']
#   - tinycss2 -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0']
#   - websocket-client -> python[version='>=3.5,<3.6.0a0']
#   - wheel -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#
# Your python: python=3.10
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package libgcc-ng conflicts for:
# anyio -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# zstd -> lz4-c[version='>=1.9.3,<1.10.0a0'] -> libgcc-ng[version='>=11.2.0']
# flit-core -> python[version='>=3.6'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# jupytext -> python[version='>=3.6'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# send2trash -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# debugpy -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.3.0|>=7.2.0']
# python=3.10 -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# python_abi -> python=3.10 -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# rfc3339-validator -> python[version='>=3.5'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# panel -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# certifi -> python[version='>=3.9,<3.10.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# websocket-client -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# argon2-cffi-bindings -> cffi[version='>=1.0.1'] -> libgcc-ng[version='>=11.2.0|>=7.3.0|>=7.2.0']
# nbclassic -> argon2-cffi -> libgcc-ng[version='>=11.2.0|>=7.3.0|>=7.5.0|>=7.2.0|>=12']
# cairo -> freetype[version='>=2.10.4,<3.0a0'] -> libgcc-ng[version='>=12']
# pygments -> python[version='>=3.5'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# lcms2 -> jpeg[version='>=9b,<10a'] -> libgcc-ng[version='>=11.2.0|>=7.2.0|>=7.5.0']
# importlib_metadata -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# pixman -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# xz -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# pcre2 -> libgcc-ng[version='>=12|>=7.3.0|>=7.5.0']
# tornado -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# packaging -> python[version='>=3.9,<3.10.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# backports.functools_lru_cache -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# libxcb -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# pango -> cairo[version='>=1.12.10'] -> libgcc-ng[version='>=7.5.0|>=9.3.0']
# cffi -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# markdown-it-py -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# rfc3986-validator -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# psutil -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# cryptography -> libgcc-ng[version='>=12|>=7.2.0|>=7.3.0']
# tk -> zlib[version='>=1.2.12,<1.3.0a0'] -> libgcc-ng[version='>=11.2.0|>=12']
# selenium -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=11.2.0']
# pyrsistent -> libgcc-ng[version='>=12|>=7.3.0|>=7.5.0']
# matplotlib -> matplotlib-base[version='>=3.6.2,<3.6.3.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=12|>=9.3.0']
# fontconfig -> expat[version='>=2.4.9,<3.0a0'] -> libgcc-ng[version='>=12|>=7.5.0|>=9.3.0']
# giflib -> libgcc-ng[version='>=11.2.0|>=7.3.0|>=7.2.0|>=7.5.0']
# jupyter_server_terminals -> python[version='>=3.8'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0']
# nbformat -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# harfbuzz -> icu[version='>=70.1,<71.0a0'] -> libgcc-ng[version='>=10.3.0']
# freetype -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# jupyter_core -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# json5 -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# libwebp-base -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=12']
# fontconfig -> libgcc-ng[version='>=11.2.0|>=7.3.0|>=7.2.0']
# pyct-core -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# pyzmq -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# nbconvert -> lxml -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# bleach -> python[version='>=3.6'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# jpeg -> libgcc-ng[version='>=12|>=7.2.0|>=7.5.0']
# argon2-cffi-bindings -> libgcc-ng[version='>=12|>=7.5.0']
# python-fastjsonschema -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# glib-tools -> libgcc-ng[version='>=12']
# pycparser -> python[version='>=3.6'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# mistune -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0']
# pkgutil-resolve-name -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# pickleshare -> python[version='>=3'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# lerc -> libgcc-ng[version='>=12|>=7.3.0|>=7.5.0']
# jupyterlab-spellchecker -> python[version='>=3.6'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# platformdirs -> python[version='>=3.9,<3.10.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# nest-asyncio -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# traitlets -> python[version='>=3.9,<3.10.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# pyyaml -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# pure_eval -> python[version='>=3.5'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# libglib -> libffi[version='>=3.4,<4.0a0'] -> libgcc-ng[version='>=10.3.0|>=11.2.0|>=7.5.0']
# importlib_resources -> python[version='>=3.6'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# sqlite -> zlib[version='>=1.2.13,<1.3.0a0'] -> libgcc-ng[version='>=12']
# tinycss2 -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# babel -> python[version='>=3.9,<3.10.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# libiconv -> libgcc-ng[version='>=10.3.0|>=7.2.0|>=7.5.0']
# gitdb -> python[version='>=3.4'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# pyzmq -> zeromq[version='>=4.3.4,<4.4.0a0'] -> libgcc-ng[version='>=9.4.0']
# ipython -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# markupsafe -> libgcc-ng[version='>=12|>=7.2.0|>=7.3.0|>=7.5.0']
# pyct -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# nbconvert-core -> markupsafe[version='>=2.0'] -> libgcc-ng[version='>=11.2.0|>=12|>=7.3.0|>=7.5.0|>=7.2.0']
# jupyterlab_server -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# wheel -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# pexpect -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# vega-lite-cli -> nodejs[version='>=18.11.0,<19.0a0'] -> libgcc-ng[version='>=12']
# selenium -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# ptyprocess -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# pyviz_comms -> python[version='>=2.7'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# setuptools -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# libdeflate -> libgcc-ng[version='>=12|>=7.3.0|>=7.5.0']
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# pytz -> python[version='>=3.9,<3.10.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# libffi -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# terminado -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=12|>=7.2.0']
# readline -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# libopenblas -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=8.2.0|>=7.2.0|>=12']
# pillow -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=8.4.0|>=7.3.0|>=7.2.0']
# altair_viewer -> python[version='>=3.6'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# gettext -> libxml2[version='>=2.9.10,<2.10.0a0'] -> libgcc-ng[version='>=7.5.0|>=9.3.0']
# altair_data_server -> python[version='>=3.6'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# bokeh -> contourpy[version='>=1'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12|>=8.4.0']
# notebook-shim -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# nbconvert-pandoc -> python[version='>=3.7'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# libuuid -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.2.0']
# vega-cli -> cairo[version='>=1.16.0,<2.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0']
# expat -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# ncurses -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# nbclient -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# toml -> python[version='>=2.7'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# zipp -> python[version='>=3.9,<3.10.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# param -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# comm -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# jupyter_server -> argon2-cffi -> libgcc-ng[version='>=11.2.0|>=7.3.0|>=7.5.0|>=7.2.0|>=12']
# python=3.10 -> bzip2[version='>=1.0.8,<2.0a0'] -> libgcc-ng[version='>=12|>=7.3.0|>=7.2.0']
# openssl -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# llvm-openmp -> zlib[version='>=1.2.12,<1.3.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=12']
# executing -> python[version='>=2.7'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# toolz -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# pyopenssl -> cryptography[version='>=35.0'] -> libgcc-ng[version='>=11.2.0|>=12|>=7.5.0|>=7.3.0|>=7.2.0']
# altair_saver -> nodejs -> libgcc-ng[version='>=11.2.0|>=12|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# fribidi -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# brotlipy -> libgcc-ng[version='>=12|>=7.3.0|>=7.5.0']
# nodejs -> openssl[version='>=1.1.1l,<1.1.2a'] -> libgcc-ng[version='>=10.3.0|>=11.2.0']
# libpng -> zlib[version='>=1.2.11,<1.3.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# libxml2 -> libgcc-ng[version='>=12|>=7.2.0|>=7.3.0|>=7.5.0|>=9.3.0']
# harfbuzz -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# prompt-toolkit -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# jedi -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# numpy -> libopenblas[version='>=0.3.2,<0.3.3.0a0'] -> libgcc-ng[version='>=8.2.0']
# debugpy -> libgcc-ng[version='>=12|>=7.5.0']
# jinja2 -> markupsafe[version='>=2.0'] -> libgcc-ng[version='>=11.2.0|>=12|>=7.3.0|>=7.5.0|>=7.2.0']
# markupsafe -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0']
# zlib -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# jupyter_events -> python[version='>=3.7'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# parso -> python[version='>=3.6'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# libglib -> libgcc-ng[version='>=12']
# zeromq -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.4.0']
# jupyter-server-mathjax -> python[version='>=3.7'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# altair -> numpy[version='>=0.18'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# matplotlib -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# charset-normalizer -> python[version='>=3.5'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# defusedxml -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# argon2-cffi -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# nbdime -> python[version='>=3.6'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# importlib-metadata -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# urllib3 -> brotlipy[version='>=0.6.0'] -> libgcc-ng[version='>=11.2.0|>=12|>=7.3.0|>=7.5.0|>=7.2.0']
# pyyaml -> yaml[version='>=0.2.5,<0.3.0a0'] -> libgcc-ng[version='>=9.4.0']
# vega-cli -> libgcc-ng[version='>=12']
# beautifulsoup4 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# python-json-logger -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# typing-extensions -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# backcall -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# prometheus_client -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# backports -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# libwebp -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# pcre2 -> zlib[version='>=1.2.11,<1.3.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.2.0']
# mdurl -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# mdit-py-plugins -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# pip -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# wcwidth -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# zstd -> libgcc-ng[version='>=12|>=7.2.0|>=7.3.0|>=7.5.0']
# smmap -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# libpng -> libgcc-ng[version='>=12|>=7.2.0|>=7.3.0']
# libzlib -> libgcc-ng[version='>=12']
# colorama -> python[version='>=3.9,<3.10.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# bzip2 -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# pyrsistent -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.2.0']
# tqdm -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# glib -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# pysocks -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# libblas -> libopenblas[version='>=0.3.21,<0.3.22.0a0'] -> libgcc-ng[version='>=11.2.0|>=12']
# soupsieve -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# ipython_genutils -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# webencodings -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# jupyterlab -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# lcms2 -> libgcc-ng[version='>=12|>=7.3.0']
# argon2-cffi -> argon2-cffi-bindings -> libgcc-ng[version='>=11.2.0|>=12|>=7.2.0']
# jupyterlab_pygments -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# zeromq -> libsodium[version='>=1.0.18,<1.0.19.0a0'] -> libgcc-ng[version='>=7.5.0']
# pandoc -> gmp -> libgcc-ng[version='>=11.2.0|>=7.2.0|>=7.3.0|>=7.5.0|>=12']
# tk -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# jsonschema -> pyrsistent[version='!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0'] -> libgcc-ng[version='>=11.2.0|>=12|>=7.3.0|>=7.5.0|>=7.2.0']
# libxml2 -> xz[version='>=5.2.5,<6.0a0'] -> libgcc-ng[version='>=10.3.0|>=11.2.0']
# numpy -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# entrypoints -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# typing_extensions -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# icu -> libgcc-ng[version='>=10.3.0|>=7.2.0|>=7.3.0']
# yaml -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.4.0']
# portpicker -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# idna -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# markdown -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# pandas -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# requests -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# gitpython -> python[version='>=3.9,<3.10.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# notebook -> argon2-cffi -> libgcc-ng[version='>=11.2.0|>=7.3.0|>=7.5.0|>=7.2.0|>=12']
# six -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# matplotlib-inline -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# pango -> libgcc-ng[version='>=11.2.0|>=7.3.0|>=7.2.0|>=12']
# libtiff -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# nodejs -> libgcc-ng[version='>=12|>=7.2.0|>=7.3.0|>=7.5.0']
# jupyterlab-git -> python[version='>=3.6,<4.0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# libsodium -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# brotlipy -> cffi[version='>=1.0.0'] -> libgcc-ng[version='>=11.2.0|>=7.2.0']
# stack_data -> python[version='>=3.5'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# sqlite -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# jupyter_client -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0|>=12']
# tomli -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# gettext -> libgcc-ng[version='>=12|>=7.2.0|>=7.3.0']
# ipykernel -> debugpy[version='>=1.0'] -> libgcc-ng[version='>=11.2.0|>=12|>=7.5.0|>=7.3.0|>=7.2.0']
# graphite2 -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# asttokens -> python[version='>=3.5'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# sniffio -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# cairo -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# mistune -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# decorator -> python[version='>=3.5'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# pillow -> freetype[version='>=2.10.4,<3.0a0'] -> libgcc-ng[version='>=12']
# python-dateutil -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# cryptography -> cffi[version='>=1.12'] -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# libuv -> libgcc-ng[version='>=12|>=7.2.0|>=7.3.0']
#
# Package zlib conflicts for:
# pkgutil-resolve-name -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# webencodings -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# platformdirs -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# bokeh -> pillow[version='>=7.1.0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# nbclassic -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# libxml2 -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0']
# argon2-cffi-bindings -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# gettext -> libxml2[version='>=2.9.10,<2.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0']
# idna -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# nodejs -> zlib[version='>=1.2.11,<1.3.0a0']
# terminado -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# notebook -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# markdown-it-py -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# stack_data -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# setuptools -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# matplotlib -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pyviz_comms -> python[version='>=2.7'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# vega-lite-cli -> nodejs[version='>=18.11.0,<19.0a0'] -> zlib
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# debugpy -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jsonschema -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# packaging -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pexpect -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# cairo -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# backcall -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# psutil -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# smmap -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# altair -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# altair_saver -> nodejs -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0|>=1.2.12,<1.3.0a0']
# nbclient -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pandoc -> zlib
# cryptography -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# libpng -> zlib[version='>=1.2.11,<1.3.0a0']
# fontconfig -> zlib[version='>=1.2.13,<1.3.0a0']
# gitpython -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pip -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# tinycss2 -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# rfc3986-validator -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# _openmp_mutex -> llvm-openmp[version='>=9.0.1'] -> zlib[version='>=1.2.12,<1.3.0a0']
# jupyterlab_pygments -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# harfbuzz -> cairo[version='>=1.16.0,<2.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pandas -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# entrypoints -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pcre2 -> zlib[version='>=1.2.11,<1.3.0a0']
# urllib3 -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# defusedxml -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# markdown -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# traitlets -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# asttokens -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# nbconvert -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# tk -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0']
# python-json-logger -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# libtiff -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# ipykernel -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# typing-extensions -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# beautifulsoup4 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyterlab-spellchecker -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# prometheus_client -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# backports.functools_lru_cache -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pure_eval -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# backports -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# mdurl -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# wcwidth -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# six -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# brotlipy -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# ptyprocess -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# vega-cli -> cairo[version='>=1.16.0,<2.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# matplotlib -> zlib[version='>=1.2.11,<1.3.0a0']
# zstd -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0']
# jupyter_client -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pyct-core -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# colorama -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# altair_viewer -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# tqdm -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pysocks -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyter_core -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# freetype -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# mdit-py-plugins -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyter_server_terminals -> python[version='>=3.8'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyter_events -> python[version='>=3.7'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# ipython_genutils -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# selenium -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pyyaml -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# send2trash -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# charset-normalizer -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# decorator -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# prompt-toolkit -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# nbdime -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# nbformat -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# json5 -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# typing_extensions -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# nbconvert-pandoc -> pandoc -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# rfc3339-validator -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jinja2 -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# portpicker -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# param -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# parso -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# websocket-client -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# importlib_resources -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# requests -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# babel -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# matplotlib-inline -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# argon2-cffi -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pyopenssl -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyterlab -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# mistune -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# importlib_metadata -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyterlab-git -> python[version='>=3.6,<4.0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# panel -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# llvm-openmp -> zlib[version='>=1.2.12,<1.3.0a0']
# certifi -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# wheel -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# sqlite -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pyrsistent -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# importlib-metadata -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pytz -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# glib -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyter-server-mathjax -> python[version='>=3.7'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# nest-asyncio -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# comm -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# python-dateutil -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# anyio -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# numpy -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# toml -> python[version='>=2.7'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# gitdb -> python[version='>=3.4'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# nbconvert-core -> python[version='>=3.7'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# altair_data_server -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pillow -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyterlab_server -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# libwebp -> libpng[version='>=1.6.37,<1.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0|>=1.2.12,<1.3.0a0']
# tomli -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jedi -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupytext -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# fontconfig -> freetype[version='>=2.10.4,<3.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0']
# pygments -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pango -> zlib[version='>=1.2.11,<1.3.0a0']
# glib -> python= -> zlib[version='>=1.2.12,<1.3.0a0']
# ipython -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pickleshare -> python[version='>=3'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# markupsafe -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# python=3.10 -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# flit-core -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# python_abi -> python=3.10 -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pyzmq -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pyct -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# notebook-shim -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# sniffio -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pango -> cairo[version='>=1.12.10'] -> zlib[version='>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# tornado -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# cffi -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# zipp -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyter_server -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# bleach -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# toolz -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# python-fastjsonschema -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# executing -> python[version='>=2.7'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pycparser -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# soupsieve -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
#
# Package gettext conflicts for:
# libglib -> gettext[version='>=0.21.1,<1.0a0']
# glib-tools -> libglib==2.74.1=h606061b_1 -> gettext[version='>=0.21.1,<1.0a0']
# harfbuzz -> glib[version='>=2.69.1,<3.0a0'] -> gettext[version='>=0.21.1,<1.0a0']
# glib -> gettext[version='>=0.21.1,<1.0a0']
# cairo -> glib[version='>=2.69.1,<3.0a0'] -> gettext[version='>=0.21.1,<1.0a0']
# vega-cli -> libglib[version='>=2.74.1,<3.0a0'] -> gettext[version='>=0.21.1,<1.0a0']
# pango -> glib[version='>=2.62,<3.0a0'] -> gettext[version='>=0.21.1,<1.0a0']
#
# Package entrypoints conflicts for:
# altair_viewer -> altair -> entrypoints
# nbconvert-core -> entrypoints[version='>=0.2.2']
# ipykernel -> jupyter_client[version='>=6.1.12'] -> entrypoints
# jupyter_client -> entrypoints
# altair -> entrypoints
# altair_data_server -> altair -> entrypoints
# nbconvert -> jupyter_client[version='>=4.2'] -> entrypoints
# nbconvert -> entrypoints[version='>=0.2.2']
# nbconvert-pandoc -> nbconvert-core==7.2.9=pyhd8ed1ab_0 -> entrypoints[version='>=0.2.2']
# jupyterlab_server -> entrypoints[version='>=0.2.2']
# nbclient -> jupyter_client[version='>=6.1.5'] -> entrypoints
# nbclassic -> jupyter_client[version='>=6.1.1'] -> entrypoints[version='>=0.2.2']
# jupyterlab -> jupyterlab_server[version='>=2.10,<3'] -> entrypoints[version='>=0.2.2']
# altair_saver -> altair -> entrypoints
# jupyter_server -> jupyter_client[version='>=6.1.12'] -> entrypoints[version='>=0.2.2']
# notebook -> jupyter_client[version='>=5.3.4'] -> entrypoints[version='>=0.2.2']
#
# Package mistune conflicts for:
# nbconvert -> mistune[version='>0.6|>=0.8.1|>=0.8.1,<2']
# jupyter_server -> nbconvert[version='>=6.4.4'] -> mistune[version='>0.6|>=0.8.1|>=0.8.1,<2|>=2.0.3,<3']
# nbclassic -> nbconvert[version='>=5'] -> mistune[version='>0.6|>=0.8.1|>=0.8.1,<2']
# notebook -> nbconvert[version='>=5'] -> mistune[version='>0.6|>=0.8.1|>=0.8.1,<2|>=2.0.3,<3']
# nbconvert -> nbconvert-core==7.2.9=pyhd8ed1ab_0 -> mistune[version='>=2.0.3,<3']
# nbconvert-pandoc -> nbconvert-core==7.2.9=pyhd8ed1ab_0 -> mistune[version='>=2.0.3,<3']
# nbconvert-core -> mistune[version='>=2.0.3,<3']
#
# Package xz conflicts for:
# jinja2 -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.6,<6.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.8,<6.0a0|>=5.2.3,<6.0a0']
# importlib-metadata -> python[version='>=3.10,<3.11.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# executing -> python[version='>=2.7'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# altair_data_server -> python[version='>=3.6'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# requests -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.6,<6.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.8,<6.0a0|>=5.2.3,<6.0a0']
# brotlipy -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.6,<6.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0|>=5.2.8,<6.0a0']
# pyrsistent -> python[version='>=3.10,<3.11.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# jedi -> python[version='>=3.10,<3.11.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# jupyter_events -> python[version='>=3.7'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0']
# jupyter_server -> python[version='>=3.10,<3.11.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# decorator -> python[version='>=3.5'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# nest-asyncio -> python[version='>=3.10,<3.11.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# soupsieve -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.6,<6.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.8,<6.0a0|>=5.2.3,<6.0a0']
# json5 -> python -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pillow -> libtiff[version='>=4.2.0,<5.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.4,<6.0a0|>=5.2.8,<6.0a0|>=5.2.6,<6.0a0|>=5.2.5,<6.0a0|>=5.2.3,<6.0a0']
# nbconvert-core -> python[version='>=3.7'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0']
# typing-extensions -> python[version='>=3.10,<3.11.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# bleach -> python[version='>=3.6'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# importlib_metadata -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.6,<6.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# send2trash -> python -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# importlib_resources -> python[version='>=3.6'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# nbclassic -> python[version='>=3.10,<3.11.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# nbdime -> python[version='>=3.6'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# cffi -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.6,<6.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.8,<6.0a0|>=5.2.3,<6.0a0']
# markdown-it-py -> python[version='>=3.10,<3.11.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0']
# argon2-cffi -> python[version='>=3.6'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# ptyprocess -> python -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# wheel -> python -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# cairo -> xz[version='>=5.2.3,<6.0a0|>=5.2.4,<6.0a0']
# gettext -> libxml2[version='>=2.9.10,<2.10.0a0'] -> xz[version='>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0']
# pyopenssl -> python[version='>=3.6'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# tqdm -> python[version='>=3.10,<3.11.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# debugpy -> python[version='>=3.10,<3.11.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# selenium -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.6,<6.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.8,<6.0a0|>=5.2.3,<6.0a0']
# toolz -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.6,<6.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.8,<6.0a0|>=5.2.3,<6.0a0']
# pycparser -> python[version='>=3.6'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pyzmq -> python[version='>=3.9,<3.10.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# tornado -> python[version='>=3.9,<3.10.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# stack_data -> python[version='>=3.5'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# backports.functools_lru_cache -> python -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pango -> cairo[version='>=1.12.10'] -> xz[version='>=5.2.3,<6.0a0|>=5.2.5,<5.3.0a0']
# ipython -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.6,<6.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.8,<6.0a0|>=5.2.3,<6.0a0']
# typing_extensions -> python[version='>=3.10,<3.11.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# toml -> python[version='>=2.7'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# markupsafe -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.6,<6.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.8,<6.0a0|>=5.2.3,<6.0a0']
# jsonschema -> python[version='>=3.10,<3.11.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# python=3.10 -> xz[version='>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0']
# jupyter_server_terminals -> python[version='>=3.8'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0']
# idna -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.6,<6.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.8,<6.0a0|>=5.2.3,<6.0a0']
# pickleshare -> python[version='>=3'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# libtiff -> xz[version='>=5.2.10,<6.0a0|>=5.2.4,<6.0a0|>=5.2.8,<6.0a0|>=5.2.6,<6.0a0|>=5.2.5,<6.0a0|>=5.2.3,<6.0a0']
# jupyterlab_server -> python[version='>=3.10,<3.11.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# babel -> python[version='>=3.9,<3.10.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# mistune -> python[version='>=3.10,<3.11.0a0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.2.6,<6.0a0|>=5.2.8,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pango -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<6.0a0']
# ...
# jupyterlab_server -> notebook[version='>=4.2.0'] -> nbclassic[version='>=0.4.7']
# notebook -> nbclassic[version='>=0.4.7']
# jupyterlab -> nbclassic[version='>=0.2,<1']
#
# Package libxml2 conflicts for:
# pango -> libxml2[version='>=2.9.10,<2.10.0a0|>=2.9.9,<2.10.0a0|>=2.9.8,<2.10.0a0']
# cairo -> fontconfig[version='>=2.14.1,<3.0a0'] -> libxml2[version='>=2.9.10,<2.10.0a0|>=2.9.14,<2.10.0a0|>=2.9.8,<2.10.0a0|>=2.9.7,<2.10.0a0|>=2.9.4,<2.10.0a0']
# pango -> fontconfig[version='>=2.13.0'] -> libxml2[version='>=2.9.14,<2.10.0a0|>=2.9.7,<2.10.0a0|>=2.9.4,<2.10.0a0']
# fontconfig -> libxml2[version='>=2.9.10,<2.10.0a0|>=2.9.14,<2.10.0a0|>=2.9.8,<2.10.0a0|>=2.9.7,<2.10.0a0|>=2.9.4,<2.10.0a0']
# nbconvert -> lxml -> libxml2[version='>=2.9.10,<2.10.0a0|>=2.9.12,<2.10.0a0|>=2.9.14,<2.10.0a0|>=2.9.2,!=2.9.11,!=2.9.12|>=2.9.9,<2.10.0a0|>=2.9.8,<2.10.0a0|>=2.9.7,<2.10.0a0|>=2.9.4,<2.10.0a0']
# gettext -> libxml2[version='>=2.9.10,<2.10.0a0']
#
# Package nbconvert-pandoc conflicts for:
# notebook -> nbconvert[version='>=5'] -> nbconvert-pandoc==7.2.9=pyhd8ed1ab_0
# nbconvert -> nbconvert-pandoc==7.2.9=pyhd8ed1ab_0
# nbclassic -> nbconvert[version='>=5'] -> nbconvert-pandoc==7.2.9=pyhd8ed1ab_0
# jupyter_server -> nbconvert[version='>=6.4.4'] -> nbconvert-pandoc==7.2.9=pyhd8ed1ab_0
#
# Package argon2-cffi-bindings conflicts for:
# nbclassic -> argon2-cffi -> argon2-cffi-bindings
# jupyter_server -> argon2-cffi -> argon2-cffi-bindings
# notebook -> argon2-cffi -> argon2-cffi-bindings
# argon2-cffi -> argon2-cffi-bindings
#
# Package executing conflicts for:
# stack_data -> executing
# ipython -> stack_data -> executing
#
# Package pandoc conflicts for:
# nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# jupyter_server -> nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# nbclassic -> nbconvert[version='>=5'] -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# notebook -> nbconvert[version='>=5'] -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# nbconvert-pandoc -> pandoc
#
# Package contextlib2 conflicts for:
# importlib_resources -> importlib_metadata -> contextlib2
# importlib_metadata -> contextlib2
# jsonschema -> importlib_metadata -> contextlib2
#
# Package asn1crypto conflicts for:
# pyopenssl -> cryptography[version='>=2.8'] -> asn1crypto[version='>=0.21.0']
# cryptography -> asn1crypto[version='>=0.21.0']
# urllib3 -> cryptography[version='>=1.3.4'] -> asn1crypto[version='>=0.21.0']
#
# Package fonts-conda-ecosystem conflicts for:
# pango -> fonts-conda-ecosystem
# vega-cli -> pango[version='>=1.50.11,<2.0a0'] -> fonts-conda-ecosystem
#
# Package glib-tools conflicts for:
# glib -> glib-tools==2.74.1=h6239696_1
# harfbuzz -> glib[version='>=2.69.1,<3.0a0'] -> glib-tools==2.74.1=h6239696_1
# cairo -> glib[version='>=2.69.1,<3.0a0'] -> glib-tools==2.74.1=h6239696_1
# pango -> glib[version='>=2.62,<3.0a0'] -> glib-tools==2.74.1=h6239696_1
#
# Package requests conflicts for:
# jupyterlab_server -> requests[version='>=2.28']
# jupyterlab -> jupyterlab_server[version='>=2.10,<3'] -> requests[version='>=2.28']
# bokeh -> requests[version='>=1.2.3']
# nbdime -> requests
# panel -> requests
# jupyterlab-git -> nbdime[version='>=3.1,<4.0'] -> requests
# pyct -> requests
#
# Package toml conflicts for:
# jupytext -> toml
# flit-core -> toml
#
# Package comm conflicts for:
# notebook -> ipykernel -> comm[version='>=0.1|>=0.1.1']
# ipykernel -> comm[version='>=0.1|>=0.1.1']
# nbclassic -> ipykernel -> comm[version='>=0.1|>=0.1.1']
#
# Package rfc3986-validator conflicts for:
# jupyter_server -> jupyter_events[version='>=0.4.0'] -> rfc3986-validator[version='>=0.1.1']
# jupyter_events -> rfc3986-validator[version='>=0.1.1']
#
# Package pure_eval conflicts for:
# ipython -> stack_data -> pure_eval
# stack_data -> pure_eval
#
# Package libwebp conflicts for:
# pillow -> libwebp[version='>=0.3.0|>=1.2.0,<1.3.0a0']
# bokeh -> pillow[version='>=7.1.0'] -> libwebp[version='>=0.3.0|>=1.2.0,<1.3.0a0']
#
# Package prompt_toolkit conflicts for:
# jupyterlab -> ipython -> prompt_toolkit[version='>=1.0.4,<2.0.0|>=2.0.0,<3|>=2.0.0,<4,!=3.0.0,!=3.0.1']
# ipykernel -> ipython[version='>=5.0'] -> prompt_toolkit[version='>=1.0.4,<2.0.0|>=2.0.0,<3|>=2.0.0,<4,!=3.0.0,!=3.0.1']
# ipython -> prompt_toolkit[version='>=1.0.4,<2.0.0|>=2.0.0,<3|>=2.0.0,<4,!=3.0.0,!=3.0.1']
#
# Package jupyterlab_server conflicts for:
# jupyterlab-spellchecker -> jupyterlab~=3.0 -> jupyterlab_server[version='>=2.10,<3|>=2.3,<3']
# jupyterlab -> jupyterlab_server[version='>=0.2.0,<0.3.0|>=1.0.0,<2.0.0|>=1.1.0,<2.0.0|>=1.1.5,<2.0.0|>=2.10,<3|>=2.3,<3']
#
# Package webencodings conflicts for:
# panel -> bleach -> webencodings
# bleach -> webencodings
# tinycss2 -> webencodings[version='>=0.4']
# nbconvert -> bleach -> webencodings[version='>=0.4']
# nbconvert-core -> bleach -> webencodings[version='>=0.4']
#
# Package gitdb2 conflicts for:
# nbdime -> gitpython[version='!=2.1.4,!=2.1.5,!=2.1.6'] -> gitdb2
# gitpython -> gitdb2
#
# Package libcblas conflicts for:
# numpy -> libcblas[version='>=3.9.0,<4.0a0']
# bokeh -> numpy[version='>=1.11.3'] -> libcblas[version='>=3.9.0,<4.0a0']
# pandas -> numpy[version='>=1.16,<2.0a0'] -> libcblas[version='>=3.9.0,<4.0a0']
# altair -> numpy[version='>=0.18'] -> libcblas[version='>=3.9.0,<4.0a0']
# matplotlib -> numpy[version='>=1.14.6,<2.0a0'] -> libcblas[version='>=3.9.0,<4.0a0']
#
# Package vega-cli conflicts for:
# altair_saver -> vega-cli
# vega-lite-cli -> vega-cli
#
# Package toolz conflicts for:
# altair -> toolz
# altair_viewer -> altair -> toolz
# altair_saver -> altair -> toolz
# altair_data_server -> altair -> toolz
#
# Package pathlib2 conflicts for:
# nbconvert -> testpath -> pathlib2
# importlib_resources -> importlib_metadata -> pathlib2
# ipykernel -> ipython[version='>=5.0'] -> pathlib2
# jupyterlab -> ipython -> pathlib2
# importlib_metadata -> pathlib2
# panel -> testpath[version='<0.4'] -> pathlib2
# ipython -> pathlib2
# pickleshare -> pathlib2
# jsonschema -> importlib_metadata -> pathlib2
#
# Package pysocks conflicts for:
# selenium -> urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# requests -> urllib3[version='>=1.21.1,<1.27'] -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
#
# Package backcall conflicts for:
# ipython -> backcall
# ipykernel -> ipython[version='>=7.23.1'] -> backcall
# jupyterlab -> ipython -> backcall
#
# Package libgfortran4 conflicts for:
# libopenblas -> libgfortran4[version='>=7.5.0']
# libopenblas -> libgfortran-ng -> libgfortran4=7.5.0
# numpy -> libopenblas[version='>=0.3.3,<1.0a0'] -> libgfortran4[version='7.5.0.*|>=7.5.0']
# libgfortran-ng -> libgfortran4=7.5.0
#
# Package asttokens conflicts for:
# stack_data -> asttokens
# ipython -> stack_data -> asttokens
#
# Package fonts-anaconda conflicts for:
# fonts-conda-ecosystem -> fonts-anaconda
# pango -> fonts-conda-ecosystem -> fonts-anaconda
#
# Package markdown-it-py conflicts for:
# jupytext -> mdit-py-plugins -> markdown-it-py[version='>=1.0.0,<3.0.0']
# mdit-py-plugins -> markdown-it-py[version='>=1.0.0,<3.0.0']
# jupytext -> markdown-it-py[version='>=1.0,<3.0']
#
# Package pkgutil-resolve-name conflicts for:
# nbformat -> jsonschema[version='>=2.6'] -> pkgutil-resolve-name[version='>=1.3.10']
# jupyter_events -> jsonschema[version='>=3.2'] -> pkgutil-resolve-name[version='>=1.3.10']
# jsonschema -> pkgutil-resolve-name[version='>=1.3.10']
# altair -> jsonschema -> pkgutil-resolve-name[version='>=1.3.10']
# jupyterlab_server -> jsonschema[version='>=3.0.1'] -> pkgutil-resolve-name[version='>=1.3.10']
#
# Package portpicker conflicts for:
# altair_saver -> altair_data_server[version='>=0.4.0'] -> portpicker
# altair_data_server -> portpicker
# altair_viewer -> altair_data_server[version='>=0.4.0'] -> portpicker
#
# Package pyrsistent conflicts for:
# nbformat -> jsonschema[version='>=2.6'] -> pyrsistent[version='!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0|>=0.14.0,!=0.17.0,!=0.17.1,!=0.17.2|>=0.14.0']
# altair -> jsonschema -> pyrsistent[version='!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0|>=0.14.0,!=0.17.0,!=0.17.1,!=0.17.2|>=0.14.0']
# jupyter_events -> jsonschema[version='>=3.2'] -> pyrsistent[version='!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0|>=0.14.0,!=0.17.0,!=0.17.1,!=0.17.2|>=0.14.0']
# jupyterlab_server -> jsonschema[version='>=3.0.1'] -> pyrsistent[version='!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0|>=0.14.0,!=0.17.0,!=0.17.1,!=0.17.2|>=0.14.0']
# jsonschema -> pyrsistent[version='!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0|>=0.14.0,!=0.17.0,!=0.17.1,!=0.17.2|>=0.14.0']
#
# Package numexpr conflicts for:
# pandas -> numexpr[version='>=2.6.8|>=2.7.0|>=2.7.1|>=2.7.3']
# altair -> pandas -> numexpr[version='>=2.6.8|>=2.7.0|>=2.7.1|>=2.7.3']
# bokeh -> pandas[version='>=1.2'] -> numexpr[version='>=2.6.8|>=2.7.0|>=2.7.1|>=2.7.3']
#
# Package giflib conflicts for:
# altair_saver -> vega-cli -> giflib[version='>=5.2.1,<5.3.0a0']
# vega-cli -> giflib[version='>=5.2.1,<5.3.0a0']
# pillow -> libwebp[version='>=1.2.0,<1.3.0a0'] -> giflib[version='>=5.1.4,<5.2.0a0|>=5.2.1,<5.3.0a0']
# libwebp -> giflib[version='>=5.1.4,<5.2.0a0|>=5.2.1,<5.3.0a0']
# vega-lite-cli -> vega-cli -> giflib[version='>=5.2.1,<5.3.0a0']
#
# Package wheel conflicts for:
# pip -> wheel
# python=3.10 -> pip -> wheel
#
# Package libgcc conflicts for:
# nodejs -> libgcc
# altair_saver -> nodejs -> libgcc
#
# Package fribidi conflicts for:
# vega-cli -> pango[version='>=1.50.11,<2.0a0'] -> fribidi[version='>=1.0.10,<2.0a0']
# pango -> fribidi[version='>=1.0.10,<2.0a0|>=1.0.6|>=1.0.9,<2.0a0|>=1.0.5,<2.0a0|>=1.0.4,<2.0a0|>=1.0.2,<2.0a0']
#
# Package lz4-c conflicts for:
# zstd -> lz4-c[version='>=1.9.2,<1.10.0a0|>=1.9.3,<1.10.0a0']
# libtiff -> zstd[version='>=1.5.2,<1.6.0a0'] -> lz4-c[version='>=1.9.2,<1.10.0a0|>=1.9.3,<1.10.0a0']
#
# Package font-ttf-inconsolata conflicts for:
# fonts-conda-forge -> font-ttf-inconsolata
# fonts-conda-ecosystem -> fonts-anaconda -> font-ttf-inconsolata
#
# Package jupyter-server-mathjax conflicts for:
# jupyterlab-git -> nbdime[version='>=3.1,<4.0'] -> jupyter-server-mathjax[version='>=0.2.2']
# nbdime -> jupyter-server-mathjax[version='>=0.2.2']
#
# Package libgomp conflicts for:
# _openmp_mutex -> libgomp[version='>=7.5.0']
# libgcc-ng -> _openmp_mutex -> libgomp[version='>=7.5.0']
#
# Package zope.interface conflicts for:
# prometheus_client -> twisted -> zope.interface[version='>=4.0.2|>=4.4.2']
# attrs -> zope.interface
#
# Package fonts-conda-forge conflicts for:
# fonts-conda-ecosystem -> fonts-conda-forge
# pango -> fonts-conda-ecosystem -> fonts-conda-forge
#
# Package font-ttf-source-code-pro conflicts for:
# fonts-conda-forge -> font-ttf-source-code-pro
# fonts-conda-ecosystem -> fonts-anaconda -> font-ttf-source-code-proThe following specifications were found to be incompatible with your system:
#
#   - feature:/linux-64::__glibc==2.35=0
#   - feature:/linux-64::__linux==4.4.0=0
#   - feature:/linux-64::__unix==0=0
#   - feature:|@/linux-64::__glibc==2.35=0
#   - feature:|@/linux-64::__linux==4.4.0=0
#   - feature:|@/linux-64::__unix==0=0
#   - altair_saver -> nodejs -> __glibc[version='>=2.17,<3.0.a0']
#   - argon2-cffi -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - argon2-cffi-bindings -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - brotlipy -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - bzip2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - cairo -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - cffi -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - cryptography -> libgcc-ng -> __glibc[version='>=2.17']
#   - debugpy -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - expat -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - fontconfig -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - freetype -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - fribidi -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - gettext -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - giflib -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - glib -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - graphite2 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - harfbuzz -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - icu -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - ipykernel -> __linux
#   - ipython -> __linux
#   - jpeg -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - jupyter_server -> terminado[version='>=0.8.3'] -> __linux
#   - jupyter_server_terminals -> terminado[version='>=0.8.3'] -> __linux
#   - jupyterlab -> ipython -> __linux
#   - lcms2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - lerc -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libdeflate -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libffi -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libgcc-ng -> __glibc[version='>=2.17']
#   - libgfortran-ng -> __glibc[version='>=2.17']
#   - libiconv -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libopenblas -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libpng -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libsodium -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libstdcxx-ng -> __glibc[version='>=2.17']
#   - libtiff -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libuuid -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libuv -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libwebp -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libwebp-base -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libxcb -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libxml2 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - markupsafe -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - matplotlib -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - mistune -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - nbclassic -> ipykernel -> __linux
#   - ncurses -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - nodejs -> __glibc[version='>=2.17,<3.0.a0']
#   - nodejs -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - notebook -> ipykernel -> __linux
#   - numpy -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - openssl -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pandas -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - pango -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - pcre2 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pillow -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - pixman -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - psutil -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - pyrsistent -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pysocks -> __unix
#   - python=3.10 -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - pyyaml -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - pyzmq -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - readline -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - selenium -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - sqlite -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - terminado -> __linux
#   - tk -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - tornado -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7'] -> __unix
#   - vega-cli -> nodejs[version='>=18.11.0,<19.0a0'] -> __glibc[version='>=2.17,<3.0.a0']
#   - vega-lite-cli -> nodejs[version='>=18.11.0,<19.0a0'] -> __glibc[version='>=2.17,<3.0.a0']
#   - xz -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - yaml -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - zeromq -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - zlib -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - zstd -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#
# Your installed version is: 4.4.0

# %%
import sys
# !{sys.executable} -m pip install --user scikit-learn # Note, the one to install is scikit-learn, not the one to be imported!
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 22.7 MB/s eta 0:00:0000:0100:01
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 6.9 MB/s eta 0:00:0000:01
# Requirement already satisfied: numpy>=1.17.3 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from scikit-learn) (1.24.1)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting scipy>=1.3.2
#   Downloading scipy-1.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 12.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.1 scipy-1.10.0 threadpoolctl-3.1.0

# %%
# !conda install -y -c conda-forge sklearn # Indeed, this is much slower than pip install above.
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - sklearn
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/linux-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %% [markdown]
# Following this to install pytorch: https://pytorch.org/get-started/locally/#windows-pip

# %%
import sys
# !{sys.executable} -m pip install --user torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cpu/torch-1.13.1%2Bcpu-cp310-cp310-linux_x86_64.whl (199.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 MB 2.3 MB/s eta 0:00:0000:0100:01
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cpu/torchvision-0.14.1%2Bcpu-cp310-cp310-linux_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 18.3 MB/s eta 0:00:0000:0100:01
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cpu/torchaudio-0.13.1%2Bcpu-cp310-cp310-linux_x86_64.whl (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 18.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from torch) (4.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from torchvision) (9.3.0)
# Requirement already satisfied: requests in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from torchvision) (2.28.2)
# Requirement already satisfied: numpy in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from torchvision) (1.24.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from requests->torchvision) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/yshen/miniconda3/envs/altair-saver-python310/lib/python3.10/site-packages (from requests->torchvision) (2.1.1)
# Installing collected packages: torch, torchvision, torchaudio
#   WARNING: The scripts convert-caffe2-to-onnx, convert-onnx-to-caffe2 and torchrun are installed in '/home/yshen/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed torch-1.13.1+cpu torchaudio-0.13.1+cpu torchvision-0.14.1+cpu

# %%
# !ls ../../
# Out:
# Direcotry-Structure-and-Workflow.org  data	     model    src
# README.md			      doc	     out.pdf  test
# config				      jupytext.toml  publish

# %%
# !conda list -e > ../../requirements-for-conda.txt

# %%
# !pip list --format=freeze > ../../requirements-with-pip.txt

# %%
conda create -y -n ac-mointor python=3.10
conda activate ac-mointor
pip3 install -r ./requirements-with-pip-doctored.txt
